# %% [markdown]
# ## Importing accidents data flow.
#
# This notebook processing FARS data (accident level granularity) into single csv file for all years between 1975-2016.
# ETL is smart enough =) to parse year level folders for accidents, vehicles, persons, convert metadata-columns to be the same for all years and enrich data values like weather type, road type, state name, etc. based on lookups which also different from year to year.
#
# ### Prerequirements:
#
# - downloading fars data, unzipping and placing into rootDir, like rootDir+'/1975', etc. (should be automated)

# %%
import warnings
warnings.filterwarnings("ignore")

from string import ascii_letters
import numpy as np
import pandas as pd

from dbfread import DBF
from pandas import DataFrame

import sys
import datetime
import os
import os.path
import zipfile
import shutil

# %%
baseDir = '/media/viktor/1E65-F3A5'
rootDir = baseDir+'/fars'  # folder with data by year, should be pre-downloaded and uziped - around 6.5 Gb
unzipedFilesTemp=baseDir+'/fars-unziped'
targetDir=baseDir+'/fars-all/'

yearList=list(range(1975,2016))
#print(yearList)

# for processing files
dir=targetDir

# %%
# List of dataframes to load data in 

df_acc={}
df_veh={}
df_per={}

df_acc_norm={}
df_veh_norm={}
df_per_norm={}

# %%
for eachYear in yearList:

    zipFile=''
    raw_masks=['FARS'+str(eachYear)+".zip",'FARSDBF'+str(eachYear)[2:4]+".zip",'FARS'+str(eachYear)+"NationalDBF.zip", 'Auxiliary_FARS_DBF_'+str(eachYear)+'.ZIP']

    for dirpath, dirnames, filenames in os.walk(rootDir):
        #print(filenames)
        for filename in [f for f in filenames if (f in raw_masks)]:
            zipFile=os.path.join(dirpath, filename)

    print(zipFile)

    if zipFile!='':

        with zipfile.ZipFile(zipFile, "r") as zip_ref:
            zip_ref.extractall(unzipedFilesTemp)

        types=[["ACC_AUX.dbf", "acc"+str(eachYear)+".dbf", "ACCIDENT.dbf", "accident.dbf", "ACCIDENT.DBF", "accident.DBF"],
               ["VEH_AUX.dbf", "veh" + str(eachYear) + ".dbf", "VEHICLE.dbf", "vehicle.dbf", "VEHICLE.DBF", "vehicle.DBF"],
               ["PER_AUX.dbf", "per" + str(eachYear) + ".dbf", "PERSON.dbf", "person.dbf", "PERSON.DBF", "person.DBF"]
             ]

        for type in types:

            for dirpath, dirnames, filenames in os.walk(unzipedFilesTemp):
                for filename in [f for f in filenames if(f in type)]:
                    typeFile = os.path.join(dirpath, filename)
                    print(typeFile)
                    shutil.move(typeFile, targetDir+'/'+str(filename.lower()[0:3])+'_'+str(eachYear)+'.dbf')
# Out:
# /media/viktor/1E65-F3A5/fars/1975/DBF/FARS1975.zip
# /media/viktor/1E65-F3A5/fars-unziped/ACCIDENT.dbf
# /media/viktor/1E65-F3A5/fars-unziped/VEHICLE.dbf
# /media/viktor/1E65-F3A5/fars-unziped/PERSON.dbf
# /media/viktor/1E65-F3A5/fars/1976/DBF/FARS1976.zip
# /media/viktor/1E65-F3A5/fars-unziped/ACCIDENT.dbf
# /media/viktor/1E65-F3A5/fars-unziped/VEHICLE.dbf
# /media/viktor/1E65-F3A5/fars-unziped/PERSON.dbf
# /media/viktor/1E65-F3A5/fars/1977/DBF/FARS1977.zip
# /media/viktor/1E65-F3A5/fars-unziped/ACCIDENT.dbf
# /media/viktor/1E65-F3A5/fars-unziped/VEHICLE.dbf
# /media/viktor/1E65-F3A5/fars-unziped/PERSON.dbf
# /media/viktor/1E65-F3A5/fars/1978/DBF/FARS1978.zip
# /media/viktor/1E65-F3A5/fars-unziped/ACCIDENT.dbf
# /media/viktor/1E65-F3A5/fars-unziped/VEHICLE.dbf
# /media/viktor/1E65-F3A5/fars-unziped/PERSON.dbf
# /media/viktor/1E65-F3A5/fars/1979/DBF/FARS1979.zip
# /media/viktor/1E65-F3A5/fars-unziped/accident.dbf
# /media/viktor/1E65-F3A5/fars-unziped/vehicle.dbf
# /media/viktor/1E65-F3A5/fars-unziped/person.dbf
# /media/viktor/1E65-F3A5/fars/1980/DBF/FARS1980.zip
# /media/viktor/1E65-F3A5/fars-unziped/accident.dbf
# /media/viktor/1E65-F3A5/fars-unziped/vehicle.dbf
# /media/viktor/1E65-F3A5/fars-unziped/person.dbf
# /media/viktor/1E65-F3A5/fars/1981/DBF/FARS1981.zip
# /media/viktor/1E65-F3A5/fars-unziped/accident.dbf
# /media/viktor/1E65-F3A5/fars-unziped/vehicle.dbf
# /media/viktor/1E65-F3A5/fars-unziped/person.dbf
# /media/viktor/1E65-F3A5/fars/1982/DBF/FARS1982.zip
# /media/viktor/1E65-F3A5/fars-unziped/accident.dbf
# /media/viktor/1E65-F3A5/fars-unziped/vehicle.dbf
# /media/viktor/1E65-F3A5/fars-unziped/person.dbf
# /media/viktor/1E65-F3A5/fars/1983/DBF/FARS1983.zip
# /media/viktor/1E65-F3A5/fars-unziped/acc1983.dbf
# /media/viktor/1E65-F3A5/fars-unziped/veh1983.dbf
# /media/viktor/1E65-F3A5/fars-unziped/per1983.dbf
# /media/viktor/1E65-F3A5/fars/1984/DBF/FARS1984.zip
# /media/viktor/1E65-F3A5/fars-unziped/acc1984.dbf
# /media/viktor/1E65-F3A5/fars-unziped/veh1984.dbf
# /media/viktor/1E65-F3A5/fars-unziped/per1984.dbf
# /media/viktor/1E65-F3A5/fars/1985/DBF/FARS1985.zip
# /media/viktor/1E65-F3A5/fars-unziped/acc1985.dbf
# /media/viktor/1E65-F3A5/fars-unziped/veh1985.dbf
# /media/viktor/1E65-F3A5/fars-unziped/per1985.dbf
# /media/viktor/1E65-F3A5/fars/1986/DBF/FARS1986.zip
# /media/viktor/1E65-F3A5/fars-unziped/acc1986.dbf
# /media/viktor/1E65-F3A5/fars-unziped/veh1986.dbf
# /media/viktor/1E65-F3A5/fars-unziped/per1986.dbf
# /media/viktor/1E65-F3A5/fars/1987/DBF/FARS1987.zip
# /media/viktor/1E65-F3A5/fars-unziped/acc1987.dbf
# /media/viktor/1E65-F3A5/fars-unziped/veh1987.dbf
# /media/viktor/1E65-F3A5/fars-unziped/per1987.dbf
# /media/viktor/1E65-F3A5/fars/1988/DBF/FARS1988.zip
# /media/viktor/1E65-F3A5/fars-unziped/acc1988.dbf
# /media/viktor/1E65-F3A5/fars-unziped/veh1988.dbf
# /media/viktor/1E65-F3A5/fars-unziped/per1988.dbf
# /media/viktor/1E65-F3A5/fars/1989/DBF/FARS1989.zip
# /media/viktor/1E65-F3A5/fars-unziped/acc1989.dbf
# /media/viktor/1E65-F3A5/fars-unziped/veh1989.dbf
# /media/viktor/1E65-F3A5/fars-unziped/per1989.dbf
# /media/viktor/1E65-F3A5/fars/1990/DBF/FARS1990.zip
# /media/viktor/1E65-F3A5/fars-unziped/acc1990.dbf
# /media/viktor/1E65-F3A5/fars-unziped/veh1990.dbf
# /media/viktor/1E65-F3A5/fars-unziped/per1990.dbf
# /media/viktor/1E65-F3A5/fars/1991/DBF/FARS1991.zip
# /media/viktor/1E65-F3A5/fars-unziped/acc1991.dbf
# /media/viktor/1E65-F3A5/fars-unziped/veh1991.dbf
# /media/viktor/1E65-F3A5/fars-unziped/per1991.dbf
# /media/viktor/1E65-F3A5/fars/1992/DBF/FARS1992.zip
# /media/viktor/1E65-F3A5/fars-unziped/acc1992.dbf
# /media/viktor/1E65-F3A5/fars-unziped/veh1992.dbf
# /media/viktor/1E65-F3A5/fars-unziped/per1992.dbf
# /media/viktor/1E65-F3A5/fars/1993/DBF/FARS1993.zip
# /media/viktor/1E65-F3A5/fars-unziped/acc1993.dbf
# /media/viktor/1E65-F3A5/fars-unziped/veh1993.dbf
# /media/viktor/1E65-F3A5/fars-unziped/per1993.dbf
# /media/viktor/1E65-F3A5/fars/1994/DBF/FARSDBF94.zip
# /media/viktor/1E65-F3A5/fars-unziped/ACCIDENT.dbf
# /media/viktor/1E65-F3A5/fars-unziped/VEHICLE.dbf
# /media/viktor/1E65-F3A5/fars-unziped/PERSON.dbf
# /media/viktor/1E65-F3A5/fars/1995/DBF/FARSDBF95.zip
# /media/viktor/1E65-F3A5/fars-unziped/ACCIDENT.dbf
# /media/viktor/1E65-F3A5/fars-unziped/VEHICLE.dbf
# /media/viktor/1E65-F3A5/fars-unziped/PERSON.dbf
# /media/viktor/1E65-F3A5/fars/1996/DBF/FARSDBF96.zip
# /media/viktor/1E65-F3A5/fars-unziped/ACCIDENT.dbf
# /media/viktor/1E65-F3A5/fars-unziped/VEHICLE.dbf
# /media/viktor/1E65-F3A5/fars-unziped/PERSON.dbf
# /media/viktor/1E65-F3A5/fars/1997/DBF/FARSDBF97.zip
# /media/viktor/1E65-F3A5/fars-unziped/ACCIDENT.dbf
# /media/viktor/1E65-F3A5/fars-unziped/VEHICLE.dbf
# /media/viktor/1E65-F3A5/fars-unziped/PERSON.dbf
# /media/viktor/1E65-F3A5/fars/1998/DBF/FARSDBF98.zip
# /media/viktor/1E65-F3A5/fars-unziped/ACCIDENT.dbf
# /media/viktor/1E65-F3A5/fars-unziped/VEHICLE.dbf
# /media/viktor/1E65-F3A5/fars-unziped/PERSON.dbf
# /media/viktor/1E65-F3A5/fars/1999/DBF/FARSDBF99.zip
# /media/viktor/1E65-F3A5/fars-unziped/ACCIDENT.dbf
# /media/viktor/1E65-F3A5/fars-unziped/VEHICLE.dbf
# /media/viktor/1E65-F3A5/fars-unziped/PERSON.dbf
# /media/viktor/1E65-F3A5/fars/2000/DBF/FARSDBF00.zip
# /media/viktor/1E65-F3A5/fars-unziped/ACCIDENT.dbf
# /media/viktor/1E65-F3A5/fars-unziped/VEHICLE.dbf
# /media/viktor/1E65-F3A5/fars-unziped/PERSON.dbf
# /media/viktor/1E65-F3A5/fars/2001/DBF/FARS2001.zip
# /media/viktor/1E65-F3A5/fars-unziped/accident.dbf
# /media/viktor/1E65-F3A5/fars-unziped/vehicle.dbf
# /media/viktor/1E65-F3A5/fars-unziped/person.dbf
# /media/viktor/1E65-F3A5/fars/2002/DBF/FARS2002.zip
# /media/viktor/1E65-F3A5/fars-unziped/accident.dbf
# /media/viktor/1E65-F3A5/fars-unziped/VEHICLE.dbf
# /media/viktor/1E65-F3A5/fars-unziped/PERSON.dbf
# /media/viktor/1E65-F3A5/fars/2003/DBF/FARS2003.zip
# /media/viktor/1E65-F3A5/fars-unziped/accident.dbf
# /media/viktor/1E65-F3A5/fars-unziped/VEHICLE.dbf
# /media/viktor/1E65-F3A5/fars-unziped/PERSON.dbf
# /media/viktor/1E65-F3A5/fars/2004/DBF/FARS2004.zip
# /media/viktor/1E65-F3A5/fars-unziped/accident.dbf
# /media/viktor/1E65-F3A5/fars-unziped/VEHICLE.dbf
# /media/viktor/1E65-F3A5/fars-unziped/PERSON.dbf
# /media/viktor/1E65-F3A5/fars/2005/DBF/FARS2005.zip
# /media/viktor/1E65-F3A5/fars-unziped/accident.dbf
# /media/viktor/1E65-F3A5/fars-unziped/VEHICLE.DBF
# /media/viktor/1E65-F3A5/fars-unziped/PERSON.DBF
# /media/viktor/1E65-F3A5/fars/2006/Auxiliary_FARS_Files/Auxiliary_FARS_DBF_2006.ZIP
# /media/viktor/1E65-F3A5/fars-unziped/FARS/ACC_AUX.dbf
# /media/viktor/1E65-F3A5/fars-unziped/FARS/VEH_AUX.dbf
# /media/viktor/1E65-F3A5/fars-unziped/FARS/PER_AUX.dbf
# /media/viktor/1E65-F3A5/fars/2007/Auxiliary_FARS_Files/Auxiliary_FARS_DBF_2007.ZIP
# /media/viktor/1E65-F3A5/fars-unziped/FARS/ACC_AUX.dbf
# /media/viktor/1E65-F3A5/fars-unziped/FARS/VEH_AUX.dbf
# /media/viktor/1E65-F3A5/fars-unziped/FARS/PER_AUX.dbf
# /media/viktor/1E65-F3A5/fars/2008/DBF/FARS2008.zip
# /media/viktor/1E65-F3A5/fars-unziped/ACCIDENT.DBF
# /media/viktor/1E65-F3A5/fars-unziped/vehicle.DBF
# /media/viktor/1E65-F3A5/fars-unziped/person.DBF
# /media/viktor/1E65-F3A5/fars/2009/DBF/FARS2009.zip
# /media/viktor/1E65-F3A5/fars-unziped/accident.DBF
# /media/viktor/1E65-F3A5/fars-unziped/vehicle.DBF
# /media/viktor/1E65-F3A5/fars-unziped/person.DBF
# /media/viktor/1E65-F3A5/fars/2010/DBF/FARS2010.zip
# /media/viktor/1E65-F3A5/fars-unziped/accident.dbf
# /media/viktor/1E65-F3A5/fars-unziped/vehicle.dbf
# /media/viktor/1E65-F3A5/fars-unziped/person.dbf
# /media/viktor/1E65-F3A5/fars/2011/DBF/FARS2011.zip
# /media/viktor/1E65-F3A5/fars-unziped/accident.dbf
# /media/viktor/1E65-F3A5/fars-unziped/vehicle.dbf
# /media/viktor/1E65-F3A5/fars-unziped/person.dbf
# /media/viktor/1E65-F3A5/fars/2012/National/DBF/FARS2012.zip
# /media/viktor/1E65-F3A5/fars-unziped/accident.dbf
# /media/viktor/1E65-F3A5/fars-unziped/vehicle.dbf
# /media/viktor/1E65-F3A5/fars-unziped/person.dbf
# /media/viktor/1E65-F3A5/fars/2013/National/FARS2013NationalDBF.zip
# /media/viktor/1E65-F3A5/fars-unziped/ACC_AUX.dbf
# /media/viktor/1E65-F3A5/fars-unziped/accident.dbf
# /media/viktor/1E65-F3A5/fars-unziped/VEH_AUX.dbf
# /media/viktor/1E65-F3A5/fars-unziped/vehicle.dbf
# /media/viktor/1E65-F3A5/fars-unziped/PER_AUX.dbf
# /media/viktor/1E65-F3A5/fars-unziped/person.dbf
# /media/viktor/1E65-F3A5/fars/2014/National/FARS2014NationalDBF.zip
# /media/viktor/1E65-F3A5/fars-unziped/ACC_AUX.dbf
# /media/viktor/1E65-F3A5/fars-unziped/accident.dbf
# /media/viktor/1E65-F3A5/fars-unziped/VEH_AUX.dbf
# /media/viktor/1E65-F3A5/fars-unziped/vehicle.dbf
# /media/viktor/1E65-F3A5/fars-unziped/PER_AUX.dbf
# /media/viktor/1E65-F3A5/fars-unziped/person.dbf
# /media/viktor/1E65-F3A5/fars/2015/National/FARS2015NationalDBF.zip
# /media/viktor/1E65-F3A5/fars-unziped/ACC_AUX.dbf
# /media/viktor/1E65-F3A5/fars-unziped/accident.dbf
# /media/viktor/1E65-F3A5/fars-unziped/VEH_AUX.dbf
# /media/viktor/1E65-F3A5/fars-unziped/vehicle.dbf
# /media/viktor/1E65-F3A5/fars-unziped/PER_AUX.dbf
# /media/viktor/1E65-F3A5/fars-unziped/person.dbf

# %%
for eachYear in yearList:
    
    dbf = DBF(dir+'acc_'+str(eachYear)+'.dbf',encoding='iso-8859-1')
    df_acc_temp = DataFrame(iter(dbf))
    df_acc[eachYear]=df_acc_temp
    #print(str(eachYear)+":"+str(df_acc_temp.shape))

# %%
for eachYear in yearList:
    
    dbf = DBF(dir+'veh_'+str(eachYear)+'.dbf',encoding='iso-8859-1')
    df_veh_temp = DataFrame(iter(dbf))
    df_veh[eachYear]=df_veh_temp
    #print(df_veh_temp.shape)

# %%
for eachYear in yearList:
    
    dbf = DBF(dir+'per_'+str(eachYear)+'.dbf',encoding='iso-8859-1')
    df_per_temp = DataFrame(iter(dbf))
    df_per[eachYear]=df_per_temp
    #print(df_per_temp.shape)

# %% [markdown]
# ### Processing data - accidents level

# %%
for eachYear in yearList:
    
    ## add custom columns mappings based on the year specific details
    
    # ------------ Year specific value fixes --------------
    
    if eachYear<=1997:
            df_acc[eachYear]['YEAR']=df_acc[eachYear]['YEAR'].apply(lambda x: x+1900 if x<100 else x)
            
    if eachYear<=1986 and 'CL_TWAY' in df_acc[eachYear]:
            df_acc[eachYear]['RoadType']=df_acc[eachYear]['CL_TWAY']
    else:
        if eachYear>=1987 and 'ROUTE' in df_acc[eachYear]:
            df_acc[eachYear]['RoadType']=df_acc[eachYear]['ROUTE']
        else:
            df_acc[eachYear]['RoadType']=np.nan
    
    # ----------- Custom mappings ---------------
    
    if 'VE_TOTAL' in df_acc[eachYear]:
        
        df_acc[eachYear]['Vehicle_count']=df_acc[eachYear]['VE_TOTAL']
        
        if ('VEHICLES' in df_acc[eachYear]) :
            if df_acc[eachYear]['VEHICLES'] is not None:
                df_acc[eachYear]['MotorVehicle_count']=df_acc[eachYear]['VEHICLES']
            else:
                if 'VE_FORMS' in df_acc[eachYear]:
                    df_acc[eachYear]['MotorVehicle_count']=df_acc[eachYear]['VE_FORMS']
        else:
            if 'VE_FORMS' in df_acc[eachYear]:
                df_acc[eachYear]['MotorVehicle_count']=df_acc[eachYear]['VE_FORMS']
            
    else:
        if 'VEHICLES' in df_acc[eachYear] and df_acc[eachYear]['VEHICLES'] is not None:
            df_acc[eachYear]['MotorVehicle_count']=df_acc[eachYear]['VEHICLES']
            df_acc[eachYear]['Vehicle_count']=df_acc[eachYear]['VEHICLES']
        else:
            if 'VE_FORMS' in df_acc[eachYear]:
                df_acc[eachYear]['MotorVehicle_count']=df_acc[eachYear]['VE_FORMS']
                df_acc[eachYear]['Vehicle_count']=df_acc[eachYear]['VE_FORMS']
    
    # ------------ General mappings --------------
    
    df_acc[eachYear].rename(columns={'COUNTY': 'COUNTRY'
                            , 'PVH_INVL': 'ParkedVehicle_count'
                            , 'PERNOTMVIT': 'PersonsOutsideVehicle_count'
                            , 'PERSONS': 'PersonsInVehicles_count'
                            , 'PEDS': 'Pedestrians_count'
                            , 'DRUNK_DR': 'DrunkDriver_count'
                            , 'FATALS': 'Fatals_count'
                            , 'LGT_COND':'LightCondition'
                            , 'REL_ROAD':'RelationToTrafficway'
                            , 'MAN_COLL':'MannerOfCollision'
                            , 'SCH_BUS':'SchoolBusRelated'
                            , 'TYP_INT':'TypeOfIntersaction'
                            , 'WEATHER':'Weather'
                            , 'NHS':'NationalHighwaySystem'
                            , 'FUNC_SYS':'FunctionalSystem'
                            , 'CF1':'CrashConditions1'
                            , 'CF2':'CrashConditions2'
                            , 'CF3':'CrashConditions3'
                            , 'HOUR':'Hour'
                            , 'MINUTE':'Minute'
                            , 'DAY_WEEK':'DayOfWeek'
                            , 'LATITUDE':'Latitude'
                            , 'LONGITUD':'Longitude'
                            , 'HOSP_HR':'HourArrivingHospital'
                            , 'HOSP_MN':'MinuteArrivingHospital'}, inplace=True)

# %%
## adding missing columns
acc_col_list=['ST_CASE','STATE', 'COUNTRY', 'CITY', 'YEAR', 'MONTH','DAY'
                            , 'Hour','Minute','DayOfWeek'
                            ,'Latitude','Longitude'
                            ,'LightCondition'
                            ,'RelationToTrafficway'
                            ,'MannerOfCollision'
                            ,'SchoolBusRelated'
                            ,'TypeOfIntersaction'
                            ,'Weather'
                            ,'NationalHighwaySystem'
                            ,'FunctionalSystem'
                            ,'RoadType'
                            ,'CrashConditions1'
                            ,'CrashConditions2'
                            ,'CrashConditions3'
                            ,'Vehicle_count'
                            ,'MotorVehicle_count'
                            ,'ParkedVehicle_count'
                            ,'PersonsOutsideVehicle_count'
                            ,'PersonsInVehicles_count'
                            ,'Pedestrians_count'
                            ,'DrunkDriver_count'
                            ,'Fatals_count']
for eachYear in yearList:
    for col in acc_col_list:
        if col in df_acc[eachYear]:
            continue
        else:
            df_acc[eachYear][col]=np.nan

# %%
## making key column & convert types

for eachYear in yearList:

    for col in acc_col_list:
        df_acc[eachYear][col] = df_acc[eachYear][col].apply(lambda x: int(x) if (x == x) and (x is not None) else np.nan)
    
    df_acc[eachYear]['CASE_NUMBER'] = df_acc[eachYear]["ST_CASE"].map(str)+"-"+ df_acc[eachYear]["STATE"].map(str)+"-"+  df_acc[eachYear]["COUNTRY"].map(str)+"-"+  df_acc[eachYear]["CITY"].map(str)+"-"+  df_acc[eachYear]["YEAR"].map(str)+"-"+  df_acc[eachYear]["MONTH"].map(str)+"-"+  df_acc[eachYear]["DAY"].map(str)

# %%
## creating order list

for eachYear in yearList:
    df_acc_norm[eachYear]=df_acc[eachYear][acc_col_list]

# %%
## TODO: prepare aggregations and join to frame: like number of accidents per year/per month/etc.

# %%
## Map categorigal values ids to values

'''
                            #State, Country, City
                            #,'LightCondition'
                            --,'RelationToTrafficway'
                            #,'MannerOfCollision'
                            #,'SchoolBusRelated'
                            #,'TypeOfIntersaction'
                            #,'Weather'
                            #,'NationalHighwaySystem'
                            --,'FunctionalSystem'
                            --,'RouteSigning'
                            --,'RoadOwnership'
                            #,'RoadType'
                            #,'CrashConditions1'
                            #,'CrashConditions2'
                            #,'CrashConditions3'
'''

stateNames = {1: 'Alabama', 2: 'Alaska', 4: 'Arizona', 5: 'Arkansas',6: 'California', 8: 'Colorado', 9: 'Connecticut', 10: 'Delaware',           11: 'District of Columbia', 12: 'Florida', 13: 'Georgia', 15: 'Hawaii',16: 'Idaho', 17: 'Illinois', 18: 'Indiana', 19: 'Iowa', 20: 'Kansas',21: 'Kentucky', 22: 'Louisiana', 23: 'Maine', 24: 'Maryland',           25: 'Massachusetts', 26: 'Michigan', 27: 'Minnesota',           28: 'Mississippi', 29: 'Missouri', 30: 'Montana', 31: 'Nebraska',           32: 'Nevada', 33: 'New Hampshire', 34: 'New Jersey', 35: 'New Mexico',           36: 'New York', 37: 'North Carolina', 38: 'North Dakota', 39: 'Ohio',           40: 'Oklahoma', 41: 'Oregon', 42: 'Pennsylvania', 43: 'Puerto Rico',           44: 'Rhode Island', 45: 'South Carolina', 46: 'South Dakota', 47: 'Tennessee',           48: 'Texas', 49: 'Utah', 50: 'Vermont', 51: 'Virginia', 52: 'Virgin Islands',           53: 'Washington', 54: 'West Virginia', 55: 'Wisconsin', 56: 'Wyoming'}

roadTypes80={0:'N/A',1:'Interstate',2:'Other Limited Access',3:'Other US Route',4:'Other State Route',5:'Other Major Artery',6:'Country Road',7:'Local Street',8:'Other Road',9:'Unknown'}
roadTypes87={0:'N/A',1:'Interstate',2:'Other US Route',3:'Other State Route',4:'Country Road',5:'Local Street',6:'Other Road',7:'Unknown',8:'Unknown',9:'Unknown'}
roadTypes16={0:'N/A',1:'Interstate',2:'US Highway',3:'State Highway',4:'Country Road',5:'Local Street-Township',6:'Local Street-Municipality',7:'Local Street-Frontage Road',8:'Other Road',9:'Unknown'}

nationalHighwaySystem={0:'Not National Highway System',1:'National Highway System',9:'Unknown'}

crashConditionBefore81={0:'None',1:'Rain/Snow/Fog/Smoke/Sand',2:'Reflected Glare / Bright Sunlight / HeadLights',3:'Curve / Hill or other design',4:'Building/Billboard',5:'Trees/Crops/Vegetation',6:'Moving vehicle',7:'Parked Vehicle',8:'Other not classified object',20:'Severe crosswind',21:'Wind form passing truck',22:'Slippery Surface',23:'Avoiding Debris',24:'Ruts/Holes/Bumps in Road',25:'Avoiding animals',26:'Avoiding vehicle',27:'Avoiding phantom veh.',28:'Avoiding pedestrian,bycicle',29:'Avoiding water/snow',40:'Traffic Controlls not functioning properly',41:'Inadequate warning of exits',42:'Uncontroller Intersection',43:'Shoulder too low or high',44:'Shoulders too narrow',47:'Other construction',48:'No or obscured Pavement Markers',49:'Surface Underwater',50:'Inadequate construction or poor design',51:'Surface washed out',99:'N/A',46:'N/A',45:'N/A'}
crashCondition82_12={0:'None',1:'Inadequate warning of exits',2:'Shoulder related',3:'Other maintainance or construction',4:'No or obscured Pavement Markers',5:'Surface Underwater',6:'Inadequate construction or poor design',7:'Surface washed out',13:'Aggressive driving',14:'Motor vehicle falling cargo',15:'Non-occupant struck by falling cargo',16:'Non-occupant struck vehicle',17:'Vehicle set in motion by non-driver',18:'Date of crash not the same date',19:'Recent previous scene crash nearby',20:'Police pursuit involved',21:'Within designated school zone',22:'Speed limit',23:'Identification of stalled vehicle',24:'Unstabillized situation began',25:'Toll plaza related',99:'N/A',46:'N/A',45:'N/A'}
crashConditionFrom13={0:'None',1:'Inadequate warning of exits',2:'Shoulder related',3:'Other maintainance or construction',4:'No or obscured Pavement Markers',5:'Surface Underwater',6:'Inadequate construction or poor design',7:'Surface washed out',13:'Aggressive driving',14:'Motor vehicle falling cargo',15:'Non-occupant struck by falling cargo',16:'Non-occupant struck vehicle',17:'Vehicle set in motion by non-driver',18:'Date of crash not the same date',19:'Recent previous scene crash nearby',20:'Police pursuit involved',21:'Within designated school zone',22:'Speed limit',23:'Identification of stalled vehicle',24:'Unstabillized situation began',25:'Toll plaza related',26:'Backup due to prior not recurring incident',27:'Backup due to prior crash',28:'Backup due to regular congestion',99:'N/A',46:'N/A',45:'N/A'}

schoolBus={0:'No',1:'Yes',8:'Not Reported'}

weatherMap75_79={1:'Clear',2:'Rain',3:'Sleet',4:'Snow',5:'N/A',6:'N/A',7:'Cloudy',8:'N/A',9:'Unknown'}
weatherMap80_81={1:'Normal',2:'Rain',3:'Sleet',4:'Snow',5:'Fog',6:'N/A',7:'N/A',8:'Smog/Smoke',9:'Unknown'}
weatherMap82_06={1:'No adverse conditions',2:'Rain',3:'Sleet',4:'Snow',5:'Fog',6:'Rain and Fog',7:'Sleet and Fog',8:'Smog/Smoke',9:'Unknown'}
weatherMap07_09={0:'No adverse conditions',1:'Clear',2:'Rain',3:'Sleet',4:'Snow',5:'Fog/Smog/Smoke',6:'Severe crosswinds',7:'Blowing sand, soil, dirt',8:'Other',9:'Unknown'}
weatherMap10_12={0:'No addictional conditions',1:'Clear',2:'Rain',3:'Sleet',4:'Snow',5:'Fog/Smog/Smoke',6:'Severe crosswinds',7:'Blowing sand, soil, dirt',8:'Other',9:'Unknown',10:'Cloudly',11:'Blowing Snow',98:'Not reported',99:'Unknown'}
weatherMap13_17={0:'No addictional conditions',1:'Clear',2:'Rain',3:'Sleet',4:'Snow',5:'Fog/Smog/Smoke',6:'Severe crosswinds',7:'Blowing sand, soil, dirt',8:'Other',9:'Unknown',10:'Cloudly',11:'Blowing Snow',12:'Freezing rain or drizzle',98:'Not reported',99:'Unknown'}

lightCondMap75_79={1:'DayLight',2:'Dark',3:'Dark but lighted',6:'Dawn or dusk',9:'Unknown'}
lightCondMap80_08={1:'DayLight',2:'Dark',3:'Dark but lighted',4:'Dawn',5:'Dusk',9:'Unknown'}
lightCondMap09={1:'DayLight',2:'Dark - not lighted',3:'Dark but lighted',4:'Dawn',5:'Dusk',6:'Dark - unknown lighting',9:'Unknown'}
lightCondMap10_17={1:'DayLight',2:'Dark - not lighted',3:'Dark but lighted',4:'Dawn',5:'Dusk',6:'Dark - unknown lighting',8:'Not reported',9:'Unknown'}

typeOfIntersactionMap={1:'Not an intersaction',2:'Four-Way intesaction',3:'T-intersaction',4:'Y-intersaction',5:'Traffic circle',6:'Roundabout',7:'Five-point or more',8:'Not reported',98:'Not reported',9:'Unknown',99:'Unknown',10:'L-intersaction'}

manColisMap75_01={0:'Not collision',1:'Rear-End',2:'Head-On',3:'Rear-to-rear',4:'Angle',5:'Sideswipe same direction',6:'Sideswipe opposite direction',7:'Sideswipe',9:'Unknown'}
manColisMap02_09={0:'Not collision',1:'Rear-End',2:'Head-On',3:'Angle front to side same direction',4:'Angle front to side opposite direction',5:'Right Angle',6:'Angle',7:'Sideswipe same direction',8:'Sideswipe opposite direction',9:'Rear-to-side',10:'Rear-to-rear',11:'Other',98:'Not reported', 99:'Unknown'}
manColisMap10_17={0:'Not collision',1:'Rear-End',2:'Head-On',6:'Angle',7:'Sideswipe same direction',8:'Sideswipe opposite direction',9:'Rear-to-side',10:'Rear-to-rear',11:'Other',98:'Not reported', 99:'Unknown'}


#---------- apply ---------

for eachYear in yearList:
    df_acc_norm[eachYear]['stateName']=df_acc_norm[eachYear]['STATE'].apply(lambda x: stateNames[x])
    
    df_acc_norm[eachYear]['RoadType']=df_acc_norm[eachYear]['RoadType'].fillna(0)
    if eachYear>=1975 and eachYear<=1980:
        df_acc_norm[eachYear]['RoadTypeName']=df_acc_norm[eachYear]['RoadType'].apply(lambda x: roadTypes80[x])
    if eachYear>1980 and eachYear<=1986:
        df_acc_norm[eachYear]['RoadTypeName']=df_acc_norm[eachYear]['RoadType'].apply(lambda x: roadTypes87[x])
    if eachYear>1986 and eachYear<=2017:
        df_acc_norm[eachYear]['RoadTypeName']=df_acc_norm[eachYear]['RoadType'].apply(lambda x: roadTypes16[x])
            
    df_acc_norm[eachYear]['NationalHighwaySystem']=df_acc_norm[eachYear]['NationalHighwaySystem'].fillna(9)
    df_acc_norm[eachYear]['NationalHighwaySystemName']=df_acc_norm[eachYear]['NationalHighwaySystem'].apply(lambda x: nationalHighwaySystem[x])

    df_acc_norm[eachYear]['CrashConditions1']=df_acc_norm[eachYear]['CrashConditions1'].fillna(99)
    df_acc_norm[eachYear]['CrashConditions2']=df_acc_norm[eachYear]['CrashConditions2'].fillna(99)
    df_acc_norm[eachYear]['CrashConditions3']=df_acc_norm[eachYear]['CrashConditions3'].fillna(99)

    if eachYear>=1975 and eachYear<=1981:
        df_acc_norm[eachYear]['CrashConditionsName1']=df_acc_norm[eachYear]['CrashConditions1'].apply(lambda x: crashConditionBefore81[x] if x in crashConditionBefore81.keys() else 'N/A')
        df_acc_norm[eachYear]['CrashConditionsName2']=df_acc_norm[eachYear]['CrashConditions2'].apply(lambda x: crashConditionBefore81[x] if x in crashConditionBefore81.keys() else 'N/A')
        df_acc_norm[eachYear]['CrashConditionsName3']=df_acc_norm[eachYear]['CrashConditions3'].apply(lambda x: crashConditionBefore81[x] if x in crashConditionBefore81.keys() else 'N/A')
    if eachYear>1981 and eachYear<=2012:
        df_acc_norm[eachYear]['CrashConditionsName1']=df_acc_norm[eachYear]['CrashConditions1'].apply(lambda x: crashCondition82_12[x] if x in crashCondition82_12.keys() else 'N/A')
        df_acc_norm[eachYear]['CrashConditionsName2']=df_acc_norm[eachYear]['CrashConditions2'].apply(lambda x: crashCondition82_12[x] if x in crashCondition82_12.keys() else 'N/A')
        df_acc_norm[eachYear]['CrashConditionsName3']=df_acc_norm[eachYear]['CrashConditions3'].apply(lambda x: crashCondition82_12[x] if x in crashCondition82_12.keys() else 'N/A')
    if eachYear>=2013 and eachYear<=2017:
        df_acc_norm[eachYear]['CrashConditionsName1']=df_acc_norm[eachYear]['CrashConditions1'].apply(lambda x: crashConditionFrom13[x] if x in crashConditionFrom13.keys() else 'N/A')
        df_acc_norm[eachYear]['CrashConditionsName2']=df_acc_norm[eachYear]['CrashConditions2'].apply(lambda x: crashConditionFrom13[x] if x in crashConditionFrom13.keys() else 'N/A')
        df_acc_norm[eachYear]['CrashConditionsName3']=df_acc_norm[eachYear]['CrashConditions3'].apply(lambda x: crashConditionFrom13[x] if x in crashConditionFrom13.keys() else 'N/A')

    df_acc_norm[eachYear]['SchoolBusRelated']=df_acc_norm[eachYear]['SchoolBusRelated'].fillna(8)
    df_acc_norm[eachYear]['SchoolBusRelatedName']=df_acc_norm[eachYear]['SchoolBusRelated'].apply(lambda x: schoolBus[x])


    if eachYear>=1975 and eachYear<=1979:
        df_acc_norm[eachYear]['WeatherName']=df_acc_norm[eachYear]['Weather'].apply(lambda x: weatherMap75_79[x] if x in weatherMap75_79.keys() else 'N/A')
    if eachYear>=1980 and eachYear<=1981:
        df_acc_norm[eachYear]['WeatherName']=df_acc_norm[eachYear]['Weather'].apply(lambda x: weatherMap80_81[x] if x in weatherMap80_81.keys() else 'N/A')
    if eachYear>=1982 and eachYear<=2006:
        df_acc_norm[eachYear]['WeatherName']=df_acc_norm[eachYear]['Weather'].apply(lambda x: weatherMap82_06[x] if x in weatherMap82_06.keys() else 'N/A')
    if eachYear>=2007 and eachYear<=2009:
        df_acc_norm[eachYear]['WeatherName']=df_acc_norm[eachYear]['Weather'].apply(lambda x: weatherMap07_09[x] if x in weatherMap07_09.keys() else 'N/A')
    if eachYear>=2010 and eachYear<=2012:
        df_acc_norm[eachYear]['WeatherName']=df_acc_norm[eachYear]['Weather'].apply(lambda x: weatherMap10_12[x] if x in weatherMap10_12.keys() else 'N/A')
    if eachYear>=2013 and eachYear<=2017:
        df_acc_norm[eachYear]['WeatherName']=df_acc_norm[eachYear]['Weather'].apply(lambda x: weatherMap13_17[x] if x in weatherMap13_17.keys() else 'N/A')

    df_acc_norm[eachYear]['LightConditionName']=np.nan    
    if eachYear>=1975 and eachYear<=1979:
        df_acc_norm[eachYear]['LightConditionName']=df_acc_norm[eachYear]['LightCondition'].apply(lambda x: lightCondMap75_79[x] if x in lightCondMap75_79.keys() else 'N/A')
    if eachYear>=1980 and eachYear<=2008:
        df_acc_norm[eachYear]['LightConditionName']=df_acc_norm[eachYear]['LightCondition'].apply(lambda x: lightCondMap80_08[x] if x in lightCondMap80_08.keys() else 'N/A')
    if eachYear==2009:
        df_acc_norm[eachYear]['LightConditionName']=df_acc_norm[eachYear]['LightCondition'].apply(lambda x: lightCondMap09[x] if x in lightCondMap09.keys() else 'N/A')
    if eachYear>=2013 and eachYear<=2017:
        df_acc_norm[eachYear]['LightConditionName']=df_acc_norm[eachYear]['LightCondition'].apply(lambda x: lightCondMap10_17[x] if x in lightCondMap10_17.keys() else 'N/A')

    df_acc_norm[eachYear]['TypeOfIntersactionName']=np.nan
    df_acc_norm[eachYear]['TypeOfIntersaction']=df_acc_norm[eachYear]['TypeOfIntersaction'].fillna(99)
    df_acc_norm[eachYear]['TypeOfIntersactionName']=df_acc_norm[eachYear]['TypeOfIntersaction'].apply(lambda x: typeOfIntersactionMap[x] if x in typeOfIntersactionMap.keys() else 'N/A')

    df_acc_norm[eachYear]['MannerOfCollisionName']=np.nan    
    if eachYear>=1975 and eachYear<=2001:
        df_acc_norm[eachYear]['MannerOfCollisionName']=df_acc_norm[eachYear]['MannerOfCollision'].apply(lambda x: manColisMap75_01[x] if x in manColisMap75_01.keys() else 'N/A')
    if eachYear>=2002 and eachYear<=2009:
        df_acc_norm[eachYear]['MannerOfCollisionName']=df_acc_norm[eachYear]['MannerOfCollision'].apply(lambda x: manColisMap02_09[x] if x in manColisMap02_09.keys() else 'N/A')
    if eachYear>=2010 and eachYear<=2017:
        df_acc_norm[eachYear]['MannerOfCollisionName']=df_acc_norm[eachYear]['MannerOfCollision'].apply(lambda x: manColisMap10_17[x] if x in manColisMap10_17.keys() else 'N/A')

# %%
## Append all years together
df_acc_all=df_acc_norm[1975]

for col in acc_col_list:
        df_acc_all[col] = df_acc_all[col].apply(lambda x: int(int(x)) if (x == x) and (x is not None) else np.nan)

for eachYear in yearList:
    if eachYear!=2015 :
        #print(eachYear+1)
        df_acc_all=df_acc_all.append(df_acc_norm[eachYear+1])

# %%
df_acc_all.shape
# Out:
# (1546170, 43)

# %%
df_acc_all.head(100)
# Out:
#     ST_CASE  STATE  COUNTRY    CITY  YEAR  MONTH   DAY  Hour  Minute  \
# 0     10001      1       95   400.0  1975    1.0   4.0  22.0    24.0
# 1     10002      1       95   110.0  1975    1.0   2.0   4.0    30.0
# 2     10003      1       35     0.0  1975    1.0   1.0   4.0     0.0
# 3     10004      1       77     0.0  1975    1.0   2.0  14.0    50.0
# 4     10005      1       97  2100.0  1975    1.0   5.0  20.0     0.0
# 5     10006      1       65     0.0  1975    1.0   4.0  15.0     0.0
# 6     10007      1       89  2225.0  1975    1.0   8.0  13.0    20.0
# 7     10008      1       69  2961.0  1975    1.0   4.0   1.0    15.0
# 8     10009      1       73  1270.0  1975    1.0   6.0  17.0    40.0
# 9     10010      1      101  2130.0  1975    1.0   3.0  17.0    44.0
# 10    10011      1        3     0.0  1975    1.0  10.0  23.0     0.0
# 11    10012      1       47     0.0  1975    1.0   5.0  17.0    48.0
# 12    10013      1      117     0.0  1975    1.0  11.0  15.0    55.0
# 13    10014      1       61     0.0  1975    1.0  10.0  22.0    50.0
# 14    10015      1      117  2405.0  1975    1.0  13.0  18.0    10.0
# 15    10016      1      101  2130.0  1975    1.0   8.0  21.0    30.0
# 16    10017      1       97  2100.0  1975    1.0  11.0  16.0     1.0
# 17    10018      1       95     0.0  1975    1.0   7.0  18.0    30.0
# 18    10019      1       99     0.0  1975    1.0  12.0   3.0    21.0
# 19    10020      1       73  1850.0  1975    1.0  17.0  99.0    99.0
# 20    10021      1       41     0.0  1975    1.0  15.0   8.0    30.0
# 21    10022      1       73   350.0  1975    1.0  25.0  17.0     0.0
# 22    10023      1      117     0.0  1975    1.0  10.0  15.0    20.0
# 23    10024      1      109     0.0  1975    1.0  18.0  18.0     0.0
# 24    10025      1       97  2100.0  1975    1.0  16.0  16.0    40.0
# 25    10026      1       83   120.0  1975    1.0   8.0  14.0    37.0
# 26    10027      1       97  2100.0  1975    1.0  17.0  19.0    48.0
# 27    10028      1       77     0.0  1975    1.0  22.0  22.0    45.0
# 28    10029      1       97  2100.0  1975    1.0  22.0  14.0    30.0
# 29    10030      1       81     0.0  1975    1.0  17.0   7.0    45.0
# ..      ...    ...      ...     ...   ...    ...   ...   ...     ...
# 70    10071      1      101  2130.0  1975    2.0   6.0   0.0    32.0
# 71    10072      1       23     0.0  1975    2.0   5.0  15.0    35.0
# 72    10073      1        5     0.0  1975    2.0  12.0   2.0    15.0
# 73    10074      1       87     0.0  1975    2.0  14.0  16.0    10.0
# 74    10075      1       99     0.0  1975    2.0   7.0  16.0    15.0
# 75    10076      1       51     0.0  1975    2.0  14.0  22.0    55.0
# 76    10077      1       15     0.0  1975    2.0  14.0  17.0    25.0
# 77    10078      1       97  2100.0  1975    2.0  11.0  20.0    28.0
# 78    10079      1      119     0.0  1975    2.0   9.0   0.0     5.0
# 79    10080      1       97     0.0  1975    2.0   8.0  11.0    50.0
# 80    10081      1       71     0.0  1975    2.0  13.0  19.0     0.0
# 81    10082      1        7     0.0  1975    2.0  13.0  14.0    40.0
# 82    10083      1       55     0.0  1975    2.0   7.0  19.0    50.0
# 83    10084      1       73   350.0  1975    2.0  14.0  20.0    15.0
# 84    10085      1      133     0.0  1975    2.0  17.0  20.0    50.0
# 85    10086      1       93     0.0  1975    2.0  18.0  10.0    30.0
# 86    10087      1       73   350.0  1975    2.0  23.0   9.0     0.0
# 87    10088      1       53     0.0  1975    2.0  21.0   3.0    30.0
# 88    10089      1      121     0.0  1975    2.0  22.0  15.0    30.0
# 89    10090      1       89  1730.0  1975    2.0  21.0  23.0    14.0
# 90    10091      1       79     0.0  1975    2.0  22.0  10.0    55.0
# 91    10092      1       43     0.0  1975    2.0  20.0  23.0    15.0
# 92    10093      1       43     0.0  1975    2.0  17.0  11.0     5.0
# 93    10094      1       89     0.0  1975    2.0  15.0  16.0     0.0
# 94    10095      1       51     0.0  1975    2.0  23.0  14.0    15.0
# 95    10096      1      121     0.0  1975    2.0  23.0  21.0     0.0
# 96    10097      1      109     0.0  1975    2.0  25.0   7.0    25.0
# 97    10098      1       87     0.0  1975    2.0  21.0  17.0    55.0
# 98    10099      1       73   350.0  1975    1.0  23.0  15.0    50.0
# 99    10100      1      117     0.0  1975    1.0  11.0  17.0    50.0
#
#     DayOfWeek          ...                 RoadTypeName  \
# 0         7.0          ...               Other US Route
# 1         5.0          ...            Other State Route
# 2         4.0          ...                 Country Road
# 3         5.0          ...                 Country Road
# 4         1.0          ...                 Local Street
# 5         7.0          ...            Other State Route
# 6         4.0          ...                 Local Street
# 7         7.0          ...                 Local Street
# 8         2.0          ...               Other US Route
# 9         6.0          ...               Other US Route
# 10        6.0          ...                   Interstate
# 11        1.0          ...               Other US Route
# 12        7.0          ...            Other State Route
# 13        6.0          ...            Other State Route
# 14        2.0          ...               Other US Route
# 15        4.0          ...                 Local Street
# 16        7.0          ...                 Local Street
# 17        3.0          ...            Other State Route
# 18        1.0          ...               Other US Route
# 19        6.0          ...                 Country Road
# 20        4.0          ...                 Country Road
# 21        7.0          ...                 Local Street
# 22        6.0          ...                 Country Road
# 23        7.0          ...            Other State Route
# 24        5.0          ...                 Local Street
# 25        4.0          ...            Other State Route
# 26        6.0          ...                 Local Street
# 27        4.0          ...                 Country Road
# 28        4.0          ...                 Local Street
# 29        6.0          ...                 Country Road
# ..        ...          ...                          ...
# 70        5.0          ...               Other US Route
# 71        4.0          ...            Other State Route
# 72        4.0          ...               Other US Route
# 73        6.0          ...                 Country Road
# 74        6.0          ...            Other State Route
# 75        6.0          ...            Other State Route
# 76        6.0          ...            Other State Route
# 77        3.0          ...                 Local Street
# 78        1.0          ...            Other State Route
# 79        7.0          ...                 Country Road
# 80        5.0          ...               Other US Route
# 81        5.0          ...                 Country Road
# 82        6.0          ...            Other State Route
# 83        6.0          ...                 Local Street
# 84        2.0          ...                 Country Road
# 85        3.0          ...            Other State Route
# 86        1.0          ...                 Local Street
# 87        6.0          ...            Other State Route
# 88        7.0          ...                 Country Road
# 89        6.0          ...                 Local Street
# 90        7.0          ...                 Country Road
# 91        5.0          ...                   Interstate
# 92        2.0          ...                 Country Road
# 93        7.0          ...                   Interstate
# 94        1.0          ...                 Country Road
# 95        1.0          ...                   Interstate
# 96        3.0          ...            Other State Route
# 97        6.0          ...            Other State Route
# 98        5.0          ...               Other US Route
# 99        7.0          ...                 Country Road
#
#     NationalHighwaySystemName          CrashConditionsName1  \
# 0                     Unknown                          None
# 1                     Unknown                          None
# 2                     Unknown                          None
# 3                     Unknown                          None
# 4                     Unknown                          None
# 5                     Unknown                          None
# 6                     Unknown                          None
# 7                     Unknown                          None
# 8                     Unknown                          None
# 9                     Unknown      Rain/Snow/Fog/Smoke/Sand
# 10                    Unknown                          None
# 11                    Unknown                          None
# 12                    Unknown                          None
# 13                    Unknown                          None
# 14                    Unknown                          None
# 15                    Unknown                          None
# 16                    Unknown                          None
# 17                    Unknown                          None
# 18                    Unknown                          None
# 19                    Unknown                          None
# 20                    Unknown                          None
# 21                    Unknown                          None
# 22                    Unknown      Rain/Snow/Fog/Smoke/Sand
# 23                    Unknown                          None
# 24                    Unknown                          None
# 25                    Unknown                          None
# 26                    Unknown                          None
# 27                    Unknown                          None
# 28                    Unknown                          None
# 29                    Unknown                          None
# ..                        ...                           ...
# 70                    Unknown                          None
# 71                    Unknown                          None
# 72                    Unknown                           N/A
# 73                    Unknown                          None
# 74                    Unknown                          None
# 75                    Unknown                          None
# 76                    Unknown                          None
# 77                    Unknown                          None
# 78                    Unknown                          None
# 79                    Unknown                          None
# 80                    Unknown                          None
# 81                    Unknown                          None
# 82                    Unknown                          None
# 83                    Unknown                          None
# 84                    Unknown                          None
# 85                    Unknown  Curve / Hill or other design
# 86                    Unknown                          None
# 87                    Unknown                          None
# 88                    Unknown                          None
# 89                    Unknown                          None
# 90                    Unknown                          None
# 91                    Unknown                          None
# 92                    Unknown  Curve / Hill or other design
# 93                    Unknown                          None
# 94                    Unknown                          None
# 95                    Unknown      Rain/Snow/Fog/Smoke/Sand
# 96                    Unknown                          None
# 97                    Unknown                          None
# 98                    Unknown                          None
# 99                    Unknown                          None
#
#     CrashConditionsName2  CrashConditionsName3  SchoolBusRelatedName  \
# 0                   None                  None          Not Reported
# 1                   None                  None          Not Reported
# 2                   None                  None          Not Reported
# 3                   None                  None          Not Reported
# 4                   None                  None          Not Reported
# 5                   None                  None          Not Reported
# 6                   None                  None          Not Reported
# 7                   None                  None          Not Reported
# 8                   None                  None          Not Reported
# 9                   None                  None          Not Reported
# 10                  None                  None          Not Reported
# 11                  None                  None          Not Reported
# 12                  None                  None          Not Reported
# 13                  None                  None          Not Reported
# 14                  None                  None          Not Reported
# 15                  None                  None          Not Reported
# 16                  None                  None          Not Reported
# 17                  None                  None          Not Reported
# 18                  None                  None          Not Reported
# 19                  None                  None          Not Reported
# 20                  None                  None          Not Reported
# 21                  None                  None          Not Reported
# 22                  None                  None          Not Reported
# 23                  None                  None          Not Reported
# 24                  None                  None          Not Reported
# 25                  None                  None          Not Reported
# 26                  None                  None          Not Reported
# 27                  None                  None          Not Reported
# 28                  None                  None          Not Reported
# 29                  None                  None          Not Reported
# ..                   ...                   ...                   ...
# 70                  None                  None          Not Reported
# 71                  None                  None          Not Reported
# 72                   N/A                   N/A          Not Reported
# 73                  None                  None          Not Reported
# 74                  None                  None          Not Reported
# 75                  None                  None          Not Reported
# 76                  None                  None          Not Reported
# 77                  None                  None          Not Reported
# 78                  None                  None          Not Reported
# 79                  None                  None          Not Reported
# 80                  None                  None          Not Reported
# 81                  None                  None          Not Reported
# 82                  None                  None          Not Reported
# 83                  None                  None          Not Reported
# 84                  None                  None          Not Reported
# 85                  None                  None          Not Reported
# 86                  None                  None          Not Reported
# 87                  None                  None          Not Reported
# 88                  None                  None          Not Reported
# 89                  None                  None          Not Reported
# 90                  None                  None          Not Reported
# 91                  None                  None          Not Reported
# 92                  None                  None          Not Reported
# 93                  None                  None          Not Reported
# 94                  None                  None          Not Reported
# 95                  None                  None          Not Reported
# 96                  None                  None          Not Reported
# 97                  None                  None          Not Reported
# 98                  None                  None          Not Reported
# 99                  None                  None          Not Reported
#
#     WeatherName  LightConditionName  TypeOfIntersactionName  \
# 0         Clear                Dark                 Unknown
# 1         Clear                Dark                 Unknown
# 2         Clear                Dark                 Unknown
# 3         Clear            DayLight                 Unknown
# 4         Clear                Dark                 Unknown
# 5         Clear            DayLight                 Unknown
# 6          Rain            DayLight                 Unknown
# 7          Rain                Dark                 Unknown
# 8         Clear        Dawn or dusk                 Unknown
# 9          Rain                Dark                 Unknown
# 10        Clear                Dark                 Unknown
# 11      Unknown                Dark                 Unknown
# 12        Clear            DayLight                 Unknown
# 13        Clear                Dark                 Unknown
# 14        Clear                Dark                 Unknown
# 15      Unknown                Dark                 Unknown
# 16        Clear            DayLight                 Unknown
# 17        Clear                Dark                 Unknown
# 18        Clear                Dark                 Unknown
# 19        Clear                Dark                 Unknown
# 20        Clear            DayLight                 Unknown
# 21        Clear        Dawn or dusk                 Unknown
# 22         Rain                Dark                 Unknown
# 23        Clear                Dark                 Unknown
# 24        Clear            DayLight                 Unknown
# 25         Rain            DayLight                 Unknown
# 26        Clear    Dark but lighted                 Unknown
# 27        Clear                Dark                 Unknown
# 28         Rain            DayLight                 Unknown
# 29        Clear                Dark                 Unknown
# ..          ...                 ...                     ...
# 70        Clear                Dark                 Unknown
# 71        Clear            DayLight                 Unknown
# 72       Cloudy                Dark                 Unknown
# 73        Clear            DayLight                 Unknown
# 74        Clear            DayLight                 Unknown
# 75        Clear    Dark but lighted                 Unknown
# 76        Clear        Dawn or dusk                 Unknown
# 77         Rain    Dark but lighted                 Unknown
# 78        Clear                Dark                 Unknown
# 79        Clear            DayLight                 Unknown
# 80        Clear                Dark                 Unknown
# 81        Clear            DayLight                 Unknown
# 82        Clear                Dark                 Unknown
# 83        Clear                Dark                 Unknown
# 84        Clear                Dark                 Unknown
# 85        Clear            DayLight                 Unknown
# 86        Clear            DayLight                 Unknown
# 87        Clear                Dark                 Unknown
# 88         Rain            DayLight                 Unknown
# 89        Clear                Dark                 Unknown
# 90        Clear            DayLight                 Unknown
# 91        Clear                Dark                 Unknown
# 92        Clear            DayLight                 Unknown
# 93        Clear            DayLight                 Unknown
# 94        Clear            DayLight                 Unknown
# 95         Rain                Dark                 Unknown
# 96        Clear            DayLight                 Unknown
# 97        Clear        Dawn or dusk                 Unknown
# 98         Rain            DayLight                 Unknown
# 99        Clear                Dark                 Unknown
#
#     MannerOfCollisionName
# 0                 Head-On
# 1           Not collision
# 2           Not collision
# 3           Not collision
# 4           Not collision
# 5                   Angle
# 6           Not collision
# 7           Not collision
# 8           Not collision
# 9                   Angle
# 10          Not collision
# 11               Rear-End
# 12          Not collision
# 13               Rear-End
# 14          Not collision
# 15          Not collision
# 16          Not collision
# 17                  Angle
# 18          Not collision
# 19          Not collision
# 20          Not collision
# 21               Rear-End
# 22          Not collision
# 23                Head-On
# 24          Not collision
# 25                Head-On
# 26          Not collision
# 27          Not collision
# 28          Not collision
# 29          Not collision
# ..                    ...
# 70          Not collision
# 71          Not collision
# 72          Not collision
# 73                  Angle
# 74                Head-On
# 75                  Angle
# 76                Head-On
# 77          Not collision
# 78          Not collision
# 79          Not collision
# 80                Head-On
# 81          Not collision
# 82          Not collision
# 83               Rear-End
# 84          Not collision
# 85                  Angle
# 86          Not collision
# 87          Not collision
# 88          Not collision
# 89          Not collision
# 90          Not collision
# 91          Not collision
# 92                Head-On
# 93               Rear-End
# 94          Not collision
# 95          Not collision
# 96                  Angle
# 97                Head-On
# 98          Not collision
# 99          Not collision
#
# [100 rows x 43 columns]

# %%
# Just to look at some values, for validation

with pd.option_context('display.max_rows', None, 'display.max_columns', 195):
    print(df_acc_all[df_acc_all.ST_CASE==10012])
# Out:
#     ST_CASE  STATE  COUNTRY    CITY  YEAR  MONTH   DAY  Hour  Minute  \
# 11    10012      1       47     0.0  1975    1.0   5.0  17.0    48.0
# 11    10012      1       65     0.0  1976    1.0  17.0  22.0    10.0
# 11    10012      1      109     0.0  1977    1.0  14.0   5.0     0.0
# 11    10012      1       97  2100.0  1978    1.0  11.0  12.0    10.0
# 10    10012      1        9  2330.0  1979    1.0   6.0  13.0    10.0
# 11    10012      1       77     0.0  1980    1.0   5.0   0.0    50.0
# 11    10012      1       23     0.0  1981    1.0   3.0  21.0    20.0
# 11    10012      1      121  2900.0  1982    1.0   8.0  16.0     8.0
# 11    10012      1       73   350.0  1983    1.0  10.0  14.0     0.0
# 11    10012      1       55     0.0  1984    1.0  14.0   2.0    10.0
# 10    10012      1       97     0.0  1985    1.0  11.0  23.0    45.0
# 10    10012      1       17     0.0  1986    1.0  12.0   4.0     0.0
# 11    10012      1       43     0.0  1987    1.0  15.0   6.0    40.0
# 11    10012      1        3     0.0  1988    1.0  16.0  20.0    19.0
# 11    10012      1       33     0.0  1989    1.0   7.0   7.0    25.0
# 11    10012      1       63     0.0  1990    1.0  17.0  18.0    15.0
# 11    10012      1       73  1850.0  1991    1.0  14.0  23.0    40.0
# 11    10012      1      111     0.0  1992    1.0  17.0  23.0    45.0
# 11    10012      1        3     0.0  1993    1.0   5.0  23.0    30.0
# 11    10012      1       29     0.0  1995    1.0   7.0  20.0    10.0
# 11    10012      1      127     0.0  1996    1.0  16.0  11.0     0.0
# 11    10012      1        7     0.0  1997    1.0  10.0  19.0    55.0
# 11    10012      1       21     0.0  1998    1.0  12.0   0.0    45.0
# 11    10012      1       97     0.0  1999    1.0  13.0   0.0    55.0
# 11    10012      1       77     0.0  2000    1.0   9.0  21.0    10.0
# 11    10012      1       53     0.0  2001    1.0   2.0  13.0    15.0
# 11    10012      1       97     0.0  2002    1.0  10.0  23.0    20.0
# 11    10012      1       57     0.0  2003    1.0  13.0   3.0     0.0
# 11    10012      1       97     0.0  2004    1.0  19.0   0.0    40.0
# 11    10012      1      121     0.0  2005    1.0   1.0   7.0    20.0
# 11    10012      1      103     NaN  2006    NaN   NaN   NaN     NaN
# 11    10012      1      117     NaN  2007    NaN   NaN   NaN     NaN
# 11    10012      1       71     0.0  2008    1.0   3.0  21.0    15.0
# 11    10012      1       21     0.0  2009    1.0  15.0  14.0    45.0
# 11    10012      1       91     0.0  2010    1.0   4.0  16.0    20.0
# 10    10012      1       83   170.0  2011    1.0   1.0  18.0    50.0
# 11    10012      1      127  1780.0  2012    1.0  22.0  19.0    49.0
# 11    10012      1        9   715.0  2013    1.0   7.0   5.0    44.0
# 11    10012      1       97  2100.0  2014    1.0   8.0  12.0    34.0
# 11    10012      1       95  1500.0  2015    1.0   9.0   6.0    35.0
#
#     DayOfWeek    Latitude    Longitude  LightCondition  RelationToTrafficway  \
# 11        1.0         NaN          NaN             2.0                   1.0
# 11        7.0         NaN          NaN             2.0                   4.0
# 11        6.0         NaN          NaN             2.0                   4.0
# 11        4.0         NaN          NaN             1.0                   1.0
# 10        7.0         NaN          NaN             1.0                   4.0
# 11        7.0         NaN          NaN             2.0                   1.0
# 11        7.0         NaN          NaN             2.0                   1.0
# 11        6.0         NaN          NaN             1.0                   1.0
# 11        2.0         NaN          NaN             1.0                   1.0
# 11        7.0         NaN          NaN             2.0                   1.0
# 10        6.0         NaN          NaN             2.0                   6.0
# 10        1.0         NaN          NaN             2.0                   4.0
# 11        5.0         NaN          NaN             1.0                   1.0
# 11        7.0         NaN          NaN             2.0                   3.0
# 11        7.0         NaN          NaN             1.0                   6.0
# 11        4.0         NaN          NaN             2.0                   1.0
# 11        2.0         NaN          NaN             2.0                   6.0
# 11        6.0         NaN          NaN             2.0                   6.0
# 11        3.0         NaN          NaN             2.0                   6.0
# 11        7.0         NaN          NaN             3.0                   6.0
# 11        3.0         NaN          NaN             1.0                   6.0
# 11        6.0         NaN          NaN             2.0                   6.0
# 11        2.0         NaN          NaN             2.0                   1.0
# 11        4.0  88888888.0  888888888.0             2.0                   1.0
# 11        1.0  88888888.0  888888888.0             2.0                   6.0
# 11        3.0         NaN          NaN             1.0                   1.0
# 11        5.0         NaN          NaN             2.0                   4.0
# 11        2.0         NaN          NaN             2.0                   4.0
# 11        2.0         NaN          NaN             2.0                   4.0
# 11        7.0         NaN          NaN             1.0                   4.0
# 11        NaN         NaN          NaN             NaN                   NaN
# 11        NaN         NaN          NaN             NaN                   NaN
# 11        5.0        34.0        -86.0             2.0                   1.0
# 11        5.0        32.0        -86.0             1.0                   4.0
# 11        2.0        31.0        -87.0             1.0                   4.0
# 10        7.0        34.0        -86.0             3.0                   1.0
# 11        1.0        33.0        -87.0             3.0                   1.0
# 11        2.0        34.0        -86.0             3.0                   1.0
# 11        4.0        30.0        -88.0             1.0                   5.0
# 11        6.0        34.0        -86.0             1.0                   1.0
#
#     MannerOfCollision  SchoolBusRelated  TypeOfIntersaction  Weather  \
# 11                1.0               8.0                99.0      9.0
# 11                0.0               8.0                99.0      1.0
# 11                0.0               0.0                99.0      2.0
# 11                4.0               0.0                99.0      1.0
# 10                0.0               0.0                99.0      2.0
# 11                2.0               0.0                99.0      1.0
# 11                0.0               0.0                99.0      1.0
# 11                4.0               0.0                99.0      1.0
# 11                4.0               0.0                99.0      1.0
# 11                5.0               0.0                99.0      1.0
# 10                0.0               0.0                99.0      1.0
# 10                0.0               0.0                99.0      1.0
# 11                2.0               0.0                99.0      2.0
# 11                0.0               0.0                99.0      1.0
# 11                0.0               0.0                99.0      1.0
# 11                4.0               0.0                99.0      2.0
# 11                0.0               0.0                99.0      1.0
# 11                0.0               0.0                99.0      1.0
# 11                0.0               0.0                99.0      1.0
# 11                0.0               0.0                99.0      1.0
# 11                0.0               0.0                99.0      1.0
# 11                0.0               0.0                99.0      1.0
# 11                1.0               0.0                99.0      1.0
# 11                0.0               0.0                99.0      1.0
# 11                0.0               0.0                99.0      1.0
# 11                0.0               0.0                99.0      1.0
# 11                0.0               0.0                99.0      1.0
# 11                0.0               0.0                99.0      3.0
# 11                0.0               0.0                99.0      1.0
# 11                0.0               0.0                99.0      1.0
# 11                NaN               8.0                99.0      NaN
# 11                NaN               8.0                99.0      NaN
# 11                2.0               0.0                99.0      1.0
# 11                0.0               0.0                99.0      1.0
# 11                0.0               0.0                 1.0      1.0
# 10                0.0               0.0                 2.0      1.0
# 11                0.0               0.0                 2.0      1.0
# 11                0.0               0.0                 1.0      1.0
# 11                0.0               0.0                 1.0      1.0
# 11                6.0               0.0                 1.0      1.0
#
#     NationalHighwaySystem  FunctionalSystem  RoadType  CrashConditions1  \
# 11                    9.0               NaN       3.0               0.0
# 11                    9.0               NaN       6.0               0.0
# 11                    9.0               NaN       3.0              99.0
# 11                    9.0               NaN       7.0               0.0
# 10                    9.0               NaN       7.0               0.0
# 11                    9.0               NaN       6.0               0.0
# 11                    9.0               NaN       0.0               0.0
# 11                    9.0               NaN       5.0               0.0
# 11                    9.0               NaN       5.0               0.0
# 11                    9.0               NaN       1.0               0.0
# 10                    9.0               NaN       3.0               0.0
# 10                    9.0               NaN       2.0               0.0
# 11                    9.0               NaN       4.0               2.0
# 11                    9.0               NaN       1.0               0.0
# 11                    9.0               NaN       4.0               0.0
# 11                    9.0               NaN       2.0               0.0
# 11                    9.0               NaN       3.0               0.0
# 11                    9.0               NaN       4.0               0.0
# 11                    9.0               NaN       3.0               0.0
# 11                    0.0               NaN       2.0               0.0
# 11                    0.0               NaN       4.0               0.0
# 11                    0.0               NaN       4.0               0.0
# 11                    1.0               NaN       1.0               0.0
# 11                    0.0               NaN       4.0               0.0
# 11                    0.0               NaN       4.0               0.0
# 11                    0.0               NaN       3.0               0.0
# 11                    0.0               NaN       4.0              20.0
# 11                    0.0               NaN       3.0               0.0
# 11                    0.0               NaN       3.0               0.0
# 11                    0.0               NaN       2.0              14.0
# 11                    9.0               NaN       0.0              99.0
# 11                    9.0               NaN       0.0              99.0
# 11                    1.0               NaN       2.0               0.0
# 11                    0.0               NaN       4.0               0.0
# 11                    0.0               NaN       4.0               0.0
# 10                    0.0               NaN       6.0               0.0
# 11                    0.0               NaN       6.0               0.0
# 11                    0.0               NaN       2.0               0.0
# 11                    1.0               NaN       6.0               0.0
# 11                    0.0               3.0       2.0               0.0
#
#     CrashConditions2  CrashConditions3  Vehicle_count  MotorVehicle_count  \
# 11               0.0               0.0            NaN                 NaN
# 11               0.0               0.0            1.0                 1.0
# 11              99.0              99.0            1.0                 1.0
# 11               0.0               0.0            2.0                 2.0
# 10               0.0               0.0            1.0                 1.0
# 11               0.0               0.0            2.0                 2.0
# 11               0.0               0.0            1.0                 1.0
# 11               0.0               0.0            2.0                 2.0
# 11               0.0               0.0            2.0                 2.0
# 11               0.0               0.0            3.0                 3.0
# 10               0.0               0.0            1.0                 1.0
# 10               0.0               0.0            1.0                 1.0
# 11               0.0               0.0            2.0                 2.0
# 11               0.0               0.0            1.0                 1.0
# 11               0.0               0.0            1.0                 1.0
# 11               0.0               0.0            2.0                 2.0
# 11               0.0               0.0            1.0                 1.0
# 11               0.0               0.0            1.0                 1.0
# 11               0.0               0.0            1.0                 1.0
# 11               0.0               0.0            1.0                 1.0
# 11               0.0               0.0            1.0                 1.0
# 11               0.0               0.0            1.0                 1.0
# 11               0.0               0.0            2.0                 2.0
# 11               0.0               0.0            1.0                 1.0
# 11               0.0               0.0            1.0                 1.0
# 11               0.0               0.0            1.0                 1.0
# 11               0.0               0.0            1.0                 1.0
# 11               0.0               0.0            1.0                 1.0
# 11               0.0               0.0            2.0                 2.0
# 11               0.0               0.0            2.0                 2.0
# 11              99.0              99.0            NaN                 NaN
# 11              99.0              99.0            NaN                 NaN
# 11               0.0               0.0            2.0                 2.0
# 11               0.0               0.0            1.0                 1.0
# 11               0.0               0.0            1.0                 1.0
# 10               0.0               0.0            1.0                 1.0
# 11               0.0               0.0            1.0                 1.0
# 11               0.0               0.0            1.0                 1.0
# 11               0.0               0.0            2.0                 1.0
# 11               0.0               0.0            3.0                 3.0
#
#     ParkedVehicle_count  PersonsOutsideVehicle_count  PersonsInVehicles_count  \
# 11                  NaN                          NaN                      2.0
# 11                  NaN                          NaN                      1.0
# 11                  NaN                          NaN                      1.0
# 11                  NaN                          NaN                      2.0
# 10                  NaN                          NaN                      1.0
# 11                  NaN                          NaN                      2.0
# 11                  NaN                          NaN                      2.0
# 11                  NaN                          NaN                      3.0
# 11                  NaN                          NaN                      4.0
# 11                  NaN                          NaN                      5.0
# 10                  NaN                          NaN                      2.0
# 10                  NaN                          NaN                      2.0
# 11                  NaN                          NaN                      3.0
# 11                  NaN                          NaN                      2.0
# 11                  NaN                          NaN                      3.0
# 11                  NaN                          NaN                      3.0
# 11                  NaN                          NaN                      2.0
# 11                  NaN                          NaN                      1.0
# 11                  NaN                          NaN                      2.0
# 11                  NaN                          NaN                      1.0
# 11                  NaN                          NaN                      1.0
# 11                  NaN                          NaN                      1.0
# 11                  NaN                          NaN                      2.0
# 11                  NaN                          NaN                      2.0
# 11                  NaN                          NaN                      3.0
# 11                  NaN                          NaN                      1.0
# 11                  NaN                          NaN                      1.0
# 11                  NaN                          NaN                      3.0
# 11                  NaN                          NaN                      2.0
# 11                  NaN                          NaN                      2.0
# 11                  NaN                          NaN                      NaN
# 11                  NaN                          NaN                      NaN
# 11                  NaN                          NaN                      4.0
# 11                  NaN                          NaN                      3.0
# 11                  NaN                          NaN                      3.0
# 10                  0.0                          1.0                      2.0
# 11                  0.0                          1.0                      1.0
# 11                  0.0                          1.0                      1.0
# 11                  1.0                          1.0                      2.0
# 11                  0.0                          0.0                      6.0
#
#     Pedestrians_count  DrunkDriver_count  Fatals_count stateName  \
# 11                NaN                0.0             1   Alabama
# 11                NaN                0.0             1   Alabama
# 11                NaN                0.0             1   Alabama
# 11                NaN                0.0             1   Alabama
# 10                NaN                0.0             1   Alabama
# 11                NaN                1.0             1   Alabama
# 11                NaN                0.0             1   Alabama
# 11                NaN                0.0             1   Alabama
# 11                NaN                0.0             2   Alabama
# 11                NaN                2.0             1   Alabama
# 10                NaN                0.0             1   Alabama
# 10                NaN                0.0             1   Alabama
# 11                NaN                0.0             2   Alabama
# 11                NaN                1.0             2   Alabama
# 11                NaN                1.0             1   Alabama
# 11                NaN                0.0             1   Alabama
# 11                0.0                1.0             1   Alabama
# 11                0.0                1.0             1   Alabama
# 11                0.0                1.0             1   Alabama
# 11                0.0                0.0             1   Alabama
# 11                0.0                0.0             1   Alabama
# 11                0.0                0.0             1   Alabama
# 11                0.0                0.0             1   Alabama
# 11                1.0                1.0             1   Alabama
# 11                0.0                1.0             1   Alabama
# 11                0.0                0.0             1   Alabama
# 11                0.0                1.0             1   Alabama
# 11                0.0                2.0             2   Alabama
# 11                0.0                1.0             1   Alabama
# 11                0.0                0.0             1   Alabama
# 11                NaN                NaN             1   Alabama
# 11                NaN                NaN             1   Alabama
# 11                0.0                0.0             2   Alabama
# 11                0.0                1.0             1   Alabama
# 11                0.0                1.0             1   Alabama
# 10                1.0                0.0             1   Alabama
# 11                1.0                0.0             1   Alabama
# 11                1.0                0.0             1   Alabama
# 11                0.0                1.0             1   Alabama
# 11                0.0                0.0             1   Alabama
#
#                  RoadTypeName    NationalHighwaySystemName  \
# 11             Other US Route                      Unknown
# 11               Country Road                      Unknown
# 11             Other US Route                      Unknown
# 11               Local Street                      Unknown
# 10               Local Street                      Unknown
# 11               Country Road                      Unknown
# 11                        N/A                      Unknown
# 11               Local Street                      Unknown
# 11               Local Street                      Unknown
# 11                 Interstate                      Unknown
# 10          Other State Route                      Unknown
# 10             Other US Route                      Unknown
# 11               Country Road                      Unknown
# 11                 Interstate                      Unknown
# 11               Country Road                      Unknown
# 11                 US Highway                      Unknown
# 11              State Highway                      Unknown
# 11               Country Road                      Unknown
# 11              State Highway                      Unknown
# 11                 US Highway  Not National Highway System
# 11               Country Road  Not National Highway System
# 11               Country Road  Not National Highway System
# 11                 Interstate      National Highway System
# 11               Country Road  Not National Highway System
# 11               Country Road  Not National Highway System
# 11              State Highway  Not National Highway System
# 11               Country Road  Not National Highway System
# 11              State Highway  Not National Highway System
# 11              State Highway  Not National Highway System
# 11                 US Highway  Not National Highway System
# 11                        N/A                      Unknown
# 11                        N/A                      Unknown
# 11                 US Highway      National Highway System
# 11               Country Road  Not National Highway System
# 11               Country Road  Not National Highway System
# 10  Local Street-Municipality  Not National Highway System
# 11  Local Street-Municipality  Not National Highway System
# 11                 US Highway  Not National Highway System
# 11  Local Street-Municipality      National Highway System
# 11                 US Highway  Not National Highway System
#
#            CrashConditionsName1 CrashConditionsName2 CrashConditionsName3  \
# 11                         None                 None                 None
# 11                         None                 None                 None
# 11                          N/A                  N/A                  N/A
# 11                         None                 None                 None
# 10                         None                 None                 None
# 11                         None                 None                 None
# 11                         None                 None                 None
# 11                         None                 None                 None
# 11                         None                 None                 None
# 11                         None                 None                 None
# 10                         None                 None                 None
# 10                         None                 None                 None
# 11             Shoulder related                 None                 None
# 11                         None                 None                 None
# 11                         None                 None                 None
# 11                         None                 None                 None
# 11                         None                 None                 None
# 11                         None                 None                 None
# 11                         None                 None                 None
# 11                         None                 None                 None
# 11                         None                 None                 None
# 11                         None                 None                 None
# 11                         None                 None                 None
# 11                         None                 None                 None
# 11                         None                 None                 None
# 11                         None                 None                 None
# 11      Police pursuit involved                 None                 None
# 11                         None                 None                 None
# 11                         None                 None                 None
# 11  Motor vehicle falling cargo                 None                 None
# 11                          N/A                  N/A                  N/A
# 11                          N/A                  N/A                  N/A
# 11                         None                 None                 None
# 11                         None                 None                 None
# 11                         None                 None                 None
# 10                         None                 None                 None
# 11                         None                 None                 None
# 11                         None                 None                 None
# 11                         None                 None                 None
# 11                         None                 None                 None
#
#    SchoolBusRelatedName            WeatherName LightConditionName  \
# 11         Not Reported                Unknown               Dark
# 11         Not Reported                  Clear               Dark
# 11                   No                   Rain               Dark
# 11                   No                  Clear           DayLight
# 10                   No                   Rain           DayLight
# 11                   No                 Normal               Dark
# 11                   No                 Normal               Dark
# 11                   No  No adverse conditions           DayLight
# 11                   No  No adverse conditions           DayLight
# 11                   No  No adverse conditions               Dark
# 10                   No  No adverse conditions               Dark
# 10                   No  No adverse conditions               Dark
# 11                   No                   Rain           DayLight
# 11                   No  No adverse conditions               Dark
# 11                   No  No adverse conditions           DayLight
# 11                   No                   Rain               Dark
# 11                   No  No adverse conditions               Dark
# 11                   No  No adverse conditions               Dark
# 11                   No  No adverse conditions               Dark
# 11                   No  No adverse conditions   Dark but lighted
# 11                   No  No adverse conditions           DayLight
# 11                   No  No adverse conditions               Dark
# 11                   No  No adverse conditions               Dark
# 11                   No  No adverse conditions               Dark
# 11                   No  No adverse conditions               Dark
# 11                   No  No adverse conditions           DayLight
# 11                   No  No adverse conditions               Dark
# 11                   No                  Sleet               Dark
# 11                   No  No adverse conditions               Dark
# 11                   No  No adverse conditions           DayLight
# 11         Not Reported                    N/A                N/A
# 11         Not Reported                    N/A                N/A
# 11                   No                  Clear               Dark
# 11                   No                  Clear           DayLight
# 11                   No                  Clear                NaN
# 10                   No                  Clear                NaN
# 11                   No                  Clear                NaN
# 11                   No                  Clear   Dark but lighted
# 11                   No                  Clear           DayLight
# 11                   No                  Clear           DayLight
#
#    TypeOfIntersactionName     MannerOfCollisionName
# 11                Unknown                  Rear-End
# 11                Unknown             Not collision
# 11                Unknown             Not collision
# 11                Unknown                     Angle
# 10                Unknown             Not collision
# 11                Unknown                   Head-On
# 11                Unknown             Not collision
# 11                Unknown                     Angle
# 11                Unknown                     Angle
# 11                Unknown  Sideswipe same direction
# 10                Unknown             Not collision
# 10                Unknown             Not collision
# 11                Unknown                   Head-On
# 11                Unknown             Not collision
# 11                Unknown             Not collision
# 11                Unknown                     Angle
# 11                Unknown             Not collision
# 11                Unknown             Not collision
# 11                Unknown             Not collision
# 11                Unknown             Not collision
# 11                Unknown             Not collision
# 11                Unknown             Not collision
# 11                Unknown                  Rear-End
# 11                Unknown             Not collision
# 11                Unknown             Not collision
# 11                Unknown             Not collision
# 11                Unknown             Not collision
# 11                Unknown             Not collision
# 11                Unknown             Not collision
# 11                Unknown             Not collision
# 11                Unknown                       N/A
# 11                Unknown                       N/A
# 11                Unknown                   Head-On
# 11                Unknown             Not collision
# 11    Not an intersaction             Not collision
# 10   Four-Way intesaction             Not collision
# 11   Four-Way intesaction             Not collision
# 11    Not an intersaction             Not collision
# 11    Not an intersaction             Not collision
# 11    Not an intersaction                     Angle

# %%
df_acc_all.to_csv(baseDir+"/Accidents1975_2015.csv")

# %%
## Finished with accidents
